# %%
# Import the required libraries

import hvplot.pandas
import pandas as pd
import requests

# %%
# Turn off warning messages

import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved, created in part one into a DataFrame. 

city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   Seybaplaya  19.6500  -90.6667     85.46        57           0
# 1        1       Atuona  -9.8000 -139.0333     77.29        76          19
# 2        2         Lebu -37.6167  -73.6500     62.64        70           0
# 3        3  Port Alfred -33.5906   26.8910     70.18        97         100
# 4        4    Busselton -33.6500  115.3333     51.13        80           0
#
#    Wind Speed Country                 Date
# 0       10.09      MX  2022-12-10 21:55:48
# 1       13.78      PF  2022-12-10 21:55:48
# 2       14.14      CL  2022-12-10 21:55:49
# 3        3.00      ZA  2022-12-10 21:55:49
# 4        9.10      AU  2022-12-10 21:55:49

# %%
# Checking DataFrame values

city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
# Configure the map plot_1

map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)

# %%
# Display the map plot_1

map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2

map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Config the map plot_3 

map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City" 
)

# Display the map plot

map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4 

map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Ask the customer to add a minimum and maximum temperature value.

min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Preferred cities dataframe based on customer input.

preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]

preferred_cities_df.head(10)
# Out:
#     City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0         0        Seybaplaya  19.6500  -90.6667     85.46        57
# 1         1            Atuona  -9.8000 -139.0333     77.29        76
# 11       11            Granja  -3.1203  -40.8261     81.07        68
# 12       12  Puerto Escondido  15.8500  -97.0667     82.76        61
# 16       16              Fare -16.7000 -151.0167     77.54        73
# 17       17              Hilo  19.7297 -155.0900     80.11        65
# 20       20             Moron -34.6534  -58.6198     86.95        58
# 22       22           Isangel -19.5500  169.2667     80.71        78
# 25       25             Kapaa  22.0752 -159.3190     80.58        67
# 29       29            Faanui -16.4833 -151.7500     76.93        76
#
#     Cloudiness  Wind Speed Country                 Date
# 0            0       10.09      MX  2022-12-10 21:55:48
# 1           19       13.78      PF  2022-12-10 21:55:48
# ...

# %%
# Determining if the preferred_cities DataFrame has any null values. 

preferred_cities_df.count()
# Out:
# City_ID       164
# City          164
# Lat           164
# Lng           164
# Max Temp      164
# Humidity      164
# Cloudiness    164
# Wind Speed    164
# Country       164
# Date          164
# dtype: int64

# %%
#Consider the following guidance:

#Depending on the time of year and the seasons, you might have to adjust the minimum and maximum temperature to get enough cities.
#It is a good idea to keep the number of cities to fewer than 200 to make it easier to plot the points on the map.
#If you have some rows with null values, you'll need to drop them using the dropna() method at the end of your filtering statement when you are creating the new DataFrame.

# %%
# Create a DataFrame called hotel_df to store hotel names
# along with city, country, max temp and coordinates. 

hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp      Lat       Lng Hotel Name
# 0         Seybaplaya      MX     85.46  19.6500  -90.6667
# 1             Atuona      PF     77.29  -9.8000 -139.0333
# 11            Granja      BR     81.07  -3.1203  -40.8261
# 12  Puerto Escondido      MX     82.76  15.8500  -97.0667
# 16              Fare      PF     77.54 -16.7000 -151.0167
# 17              Hilo      US     80.11  19.7297 -155.0900
# 20             Moron      AR     86.95 -34.6534  -58.6198
# 22           Isangel      VU     80.71 -19.5500  169.2667
# 25             Kapaa      US     80.58  22.0752 -159.3190
# 29            Faanui      PF     76.93 -16.4833 -151.7500

# %%
# Adding Hotel API key.
from config import hotel_key

# %%
# Set initial parameters to search for a hotel. 

radius = 5000

params = {
    "categories":"accommodation.hotel",
    "apiKey": hotel_key,
}

# %%
# Iterate through the hotel_df DataFrame

for index, row in hotel_df.iterrows():
    
    # Get latitude and longitude from DataFrame. 
    
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    
    # Set up the base URL for the Geoapify Places API
    
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name 
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
        
    except (KeyError, IndexError):
            
        # If no hot is found, set the hotel name as "No hotel found."
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

# %%
hotel_df.head(10)
# Out:
#                 City Country  Max Temp      Lat       Lng  \
# 0         Seybaplaya      MX     85.46  19.6500  -90.6667
# 1             Atuona      PF     77.29  -9.8000 -139.0333
# 11            Granja      BR     81.07  -3.1203  -40.8261
# 12  Puerto Escondido      MX     82.76  15.8500  -97.0667
# 16              Fare      PF     77.54 -16.7000 -151.0167
# 17              Hilo      US     80.11  19.7297 -155.0900
# 20             Moron      AR     86.95 -34.6534  -58.6198
# 22           Isangel      VU     80.71 -19.5500  169.2667
# 25             Kapaa      US     80.58  22.0752 -159.3190
# 29            Faanui      PF     76.93 -16.4833 -151.7500
#
#                              Hotel Name
# 0                        No hotel found
# 1                          Pearl Resort
# 11                          Casa Grande
# 12              Hotel Paraiso Escondido
# 16          hôtel Maitai Lapita Village
# 17                    Dolphin Bay Hotel
# ...

# %%
# Configure the map

hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map

hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
