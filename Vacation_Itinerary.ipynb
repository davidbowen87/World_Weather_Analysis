# %% [markdown]
# # Deliverable 3. Create a Travel Itinerary Map
#
# ----
#
# 1. Create a folder called `Vacation_Itinerary` to store all the files for this deliverable.
#
# 2. Download the `Vacation_Itinerary_starter_code.ipynb` file into your `Vacation_Itinerary` folder and rename it `Vacation_Itinerary.ipynb`.
#
# 3. Make sure the initial dependencies and the Geoapify API key are imported.
#
# 4. From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`.
#
# 5. Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
#     * The point's size should be the maximum temperature for the city
#
#     * The point's color should be the city's name
#
#     * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.
#
# 6. From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.
#
#     > **Hint:** You will start and end the route in the same city, so the `vacation_start` and `vacation_end` DataFrames will be in the same city.
#
# 7. Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details.
#
# 8. Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`.
#
#     > **Hint:** You'll use this DataFrame to create a map using GeoViews, so recall that the first column should be the longitude, and the second the latitude.
#
# 9. Use GeoViews to create a map that shows the four cities in the itinerary.
#
# 10. Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop.
#
#     > **Hint:** You can note that the `mode` parameter is set to `drive`, you can play around with other modes as it's shown in [the "Travel modes" table](https://apidocs.geoapify.com/docs/routing/#api) in the Geoapify Routing API documentation.
#
# 11. Use the Geoapify Routing API to retrieve the route's directions for your itinerary.
#
# 12. From the JSON response, store the route's legs coordinates in a variable called `legs`.
#
# 13. Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude values into two Python lists named `longitude` and `latitude`.
#
# 14. Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`.
#
# 15. Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map.
#
# 16. Use the asterisk operator to display a composed plot that shows the itinerary's route over the map containing the cities.
#
# 17. Save your map to the `Vacation_Itinerary` folder as `WeatherPy_travel_map.png`.
#
# ---

# %% [markdown]
# ## Make sure the initial dependencies and the Geoapify API key are imported

# %%
# Dependencies and Setup
import geoviews as gv
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`

# %%
# Read the WeatherPy_vacation.csv into a DataFrame
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")

# Display sample data
vacation_df.head(5)
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0        1    Meulaboh      ID     74.10     overcast clouds   4.1363
# 1        2        Atar      MR     76.57           clear sky  20.5169
# 2        8  Gold Coast      AU     83.16     overcast clouds -28.0000
# 3        9       Kapaa      US     84.18       broken clouds  22.0752
# 4       11   Sotouboua      TG     75.61           clear sky   8.5667
#
#         Lng       Hotel Name
# 0   96.1285   Hotel Meuligou
# 1  -13.0499       فندق سكليل
# 2  153.4333           Zenith
# 3 -159.3190  Pono Kai Resort
# 4    0.9833           Verger

# %% [markdown]
# ## Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
# * The point's size should be the maximum temperature for the city
#
# * The point's color should be the city's name
#
# * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

# %%
# Configure the map plot
map_plot = vacation_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Max Temp,Hotel Name,Country,Current Description)

# %% [markdown]
# ## From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.

# %%
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method
vacation_start = vacation_df.loc[vacation_df["City_ID"] == 305]
vacation_end = vacation_df.loc[vacation_df["City_ID"] == 305]
vacation_stop1 = vacation_df.loc[vacation_df["City_ID"] == 346]
vacation_stop2 = vacation_df.loc[vacation_df["City_ID"] == 578]
vacation_stop3 = vacation_df.loc[vacation_df["City_ID"] == 600]

# %% [markdown]
# ## Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details

# %%
# Use the Pandas concat function to create a new DataFrame to store the itinerary details.
itinerary_df = itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2,
                                         vacation_stop3, vacation_end])

# Display sample data
itinerary_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 73       305         Acapulco      MX     78.15    scattered clouds  16.8634
# 82       346     Isla Mujeres      MX     75.25           clear sky  21.2311
# 127      578           Carmen      MX     78.84          few clouds  18.6333
# 133      600  Lazaro Cardenas      MX     77.79           clear sky  17.9583
# 73       305         Acapulco      MX     78.15    scattered clouds  16.8634
#
#           Lng              Hotel Name
# 73   -99.8901         Hotel del Valle
# 82   -86.7310          Villa La Bella
# 127  -91.8333     Holiday Inn Express
# 133 -102.2000  Hotel Sol del Pacífico
# 73   -99.8901         Hotel del Valle

# %% [markdown]
# ## Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`

# %%
# Create a Pandas DataFrame to store the latitude and longitude for each city in the itineray
waypoints_df = itinerary_df[["Lng", "Lat"]].copy()

# Display sample data
waypoints_df
# Out:
#           Lng      Lat
# 73   -99.8901  16.8634
# 82   -86.7310  21.2311
# 127  -91.8333  18.6333
# 133 -102.2000  17.9583
# 73   -99.8901  16.8634

# %% [markdown]
# ## Use GeoViews to create map that shows the four cities in the itinerary

# %%
# Configure the map plot by using the itineraty_df
waypoints_map = waypoints_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 1,
    color = "purple")

# %%
# Display the route_map
waypoints_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %% [markdown]
# ## Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop

# %%
# Set parameters to trace the route
radius = 5000
params = {
    "mode":"drive",
    "apiKey": geoapify_key,
}

# %%
# Set an empty waypoints String variable
waypoints = ""

# Iterate through the route_df DataFrame to define the waypoints
for index, row in waypoints_df.iterrows():
    waypoints = waypoints + str(row["Lat"]) + "," + str(row["Lng"]) + "|"

# Delete the last character from the string
waypoints = waypoints[:-1]

# Add the waypoints to the params dictionary
params["waypoints"] = waypoints

# Display the params dictionary
params
# Out:
# {'mode': 'drive',
#  'apiKey': '48bfb7c90c424406b8af14821aab4a04',
#  'waypoints': '16.8634,-99.8901|21.2311,-86.731|18.6333,-91.8333|17.9583,-102.2|16.8634,-99.8901'}

# %% [markdown]
# ## Use the Geoapify Routing API to retrieve the route's directions for your itinerary

# %%
# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v1/routing"

# Make request and retrieve the JSON data by using the params dictionaty
route_response = requests.get(base_url, params=params)

# Convert the API response to JSON format
route_response = route_response.json()
route_response
# Out:
# {'features': [{'type': 'Feature',
#    'properties': {'mode': 'drive',
#     'waypoints': [{'location': [-99.8901, 16.8634], 'original_index': 0},
#      {'location': [-86.731, 21.2311], 'original_index': 1},
#      {'location': [-91.8333, 18.6333], 'original_index': 2},
#      {'location': [-102.2, 17.9583], 'original_index': 3},
#      {'location': [-99.8901, 16.8634], 'original_index': 4}],
#     'units': 'metric',
#     'distance': 4491312,
#     'distance_units': 'meters',
#     'time': 167823.755,
#     'legs': [{'distance': 1915353,
#       'time': 71542.234,
#       'steps': [{'from_index': 0,
#         'to_index': 1,
#         'distance': 30,
#         'time': 3.676,
#         'instruction': {'text': 'Drive south on Calle Vicente Guerrero.'}},
#        {'from_index': 1,
#         'to_index': 3,
#         'distance': 44,
#         'time': 11.016,
#         'instruction': {'text': 'Turn left onto Avenida Sonora.'}},
#        {'from_index': 3,
#         'to_index': 5,
#         'distance': 208,
#         'time': 27.305,
#         'instruction': {'text': 'Turn right onto Calle Caminos.'}},
#        {'from_index': 5,
#         'to_index': 31,
#         'distance': 2199,
#         'time': 144.078,
#         'instruction': {'text': 'Turn left onto Avenida Cuauhtémoc.'}},
#        {'from_index': 31,
#         'to_index': 2505,
#         'distance': 239843,
#         'time': 8367.161,
#         'instruction': {'text': 'Bear right onto MEX 95D.'},
#         'toll': True},
#        {'from_index': 2505,
#         'to_index': 3528,
#         'distance': 116625,
#         'time': 3920.989,
#         'instruction': {'text': 'Take the Autopista Jantetelco - El Higuerón exit.'},
#         'toll': True},
#        {'from_index': 3528,
#         'to_index': 3904,
#         'distance': 19650,
#         'time': 722.248,
#         'instruction': {'text': 'Take the MEX 190D exit toward Puebla.'},
#         'toll': True},
#        {'from_index': 3904,
#         'to_index': 3955,
#         'distance': 1777,
#         'time': 85.578,
#         'instruction': {'text': 'Make a sharp left toward MEX 190D.'}},
#        {'from_index': 3955,
#         'to_index': 3962,
#         'distance': 295,
#         'time': 18.705,
#         'instruction': {'text': 'Keep right to stay on Boulevard Vía Atlixcáyotl toward Mexico.'}},
#        {'from_index': 3962,
#         'to_index': 3986,
#         'distance': 373,
#         'time': 15.6,
#         'instruction': {'text': 'Take the exit toward Mexico.'}},
#        {'from_index': 3986,
#         'to_index': 4009,
#         'distance': 229,
#         'time': 11.734,
#         'instruction': {'text': 'Take the ramp on the left toward Acapulco/Atlixco.'}},
#        {'from_index': 4009,
#         'to_index': 4032,
#         'distance': 442,
#         'time': 22.135,
#         'instruction': {'text': 'Keep left toward Puebla/Valsequillo.'}},
#        {'from_index': 4032,
#         'to_index': 4039,
#         'distance': 124,
#         'time': 6.232,
#         'instruction': {'text': 'Keep left at the fork.'}},
#        {'from_index': 4039,
#         'to_index': 4385,
#         'distance': 24042,
#         'time': 966.151,
#         'instruction': {'text': 'Keep right to take Boulevard Periférico Ecológico toward Valsequillo.'}},
#        {'from_index': 4385,
#         'to_index': 6077,
#         'distance': 171861,
#         'time': 5915.603,
#         'instruction': {'text': 'Take the MEX 150D ramp on the left toward Veracruz/Perote.'},
#         'toll': True},
#        {'from_index': 6077,
#         'to_index': 6351,
#         'distance': 30942,
#         'time': 1016.576,
#         'instruction': {'text': 'Keep left to stay on MEX 150D.'}},
#        {'from_index': 6351,
#         'to_index': 7662,
#         'distance': 250818,
#         'time': 8501.457,
#         'instruction': {'text': 'Keep right to take MEX 145D.'},
#         'toll': True},
#        {'from_index': 7662,
#         'to_index': 7813,
#         'distance': 11119,
#         'time': 381.392,
#         'instruction': {'text': 'Keep left to take MEX 180D.'},
#         'toll': True},
#        {'from_index': 7813,
#         'to_index': 8605,
#         'distance': 139216,
#         'time': 5207.83,
#         'instruction': {'text': 'Keep right to take MEX 180 toward Merida/Villahermosa.'}},
#        {'from_index': 8605,
#         'to_index': 8706,
#         'distance': 21925,
#         'time': 758.359,
#         'instruction': {'text': 'Take the MEX 180D ramp.'},
#         'toll': True},
#        {'from_index': 8706,
#         'to_index': 9366,
#         'distance': 117112,
#         'time': 4754.019,
#         'instruction': {'text': 'Take the MEX 180 exit toward Frontera/Ciudad Del Carmen.'}},
#        {'from_index': 9366,
#         'to_index': 9764,
#         'distance': 50701,
#         'time': 2085.941,
#         'instruction': {'text': 'Keep left to stay on MEX 180.'},
#         'toll': True},
#        {'from_index': 9764,
#         'to_index': 10045,
#         'distance': 37646,
#         'time': 1623.488,
#         'instruction': {'text': 'Turn left to stay on MEX 180.'},
#         'toll': True},
#        {'from_index': 10045,
#         'to_index': 10048,
#         'distance': 8,
#         'time': 0.8,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto MEX 180/Avenida Puente de la Unidad.'}},
#        {'from_index': 10048,
#         'to_index': 10668,
#         'distance': 123269,
#         'time': 5132.406,
#         'instruction': {'text': 'Exit the roundabout onto MEX 180/Avenida Puente de la Unidad. Continue on MEX 180.'}},
#        {'from_index': 10668,
#         'to_index': 10867,
#         'distance': 38807,
#         'time': 1270.152,
#         'instruction': {'text': 'Keep left to take MEX 180D/Autopista de Peaje Champotón-Campeche.'},
#         'toll': True},
#        {'from_index': 10867,
#         'to_index': 11780,
#         'distance': 165390,
#         'time': 6577.164,
#         'instruction': {'text': 'Take the MEX 180 exit.'}},
#        {'from_index': 11780,
#         'to_index': 11905,
#         'distance': 13995,
#         'time': 564.753,
#         'instruction': {'text': 'Take the Anillo Periférico Licenciado Manuel Berzunza exit.'}},
#        {'from_index': 11905,
#         'to_index': 11912,
#         'distance': 379,
#         'time': 34.21,
#         'instruction': {'text': 'Keep right to take Calle 10.'}},
#        {'from_index': 11912,
#         'to_index': 11913,
#         'distance': 12,
#         'time': 2.339,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit onto MEX 180.'}},
#        {'from_index': 11913,
#         'to_index': 12272,
#         'distance': 59762,
#         'time': 2423.73,
#         'instruction': {'text': 'Exit the roundabout onto MEX 180.'}},
#        {'from_index': 12272,
#         'to_index': 12301,
#         'distance': 2230,
#         'time': 76.535,
#         'instruction': {'text': 'Keep left to take MEX 180/Autopista Kantunil-Cancún.'},
#         'toll': True},
#        {'from_index': 12301,
#         'to_index': 12316,
#         'distance': 690,
#         'time': 22.644,
#         'instruction': {'text': 'Keep left to take MEX 180D/Autopista Kantunil-Cancún.'},
#         'toll': True},
#        {'from_index': 12316,
#         'to_index': 12521,
#         'distance': 169314,
#         'time': 5585.003,
#         'instruction': {'text': 'Take the MEX 180D exit on the left.'},
#         'toll': True},
#        {'from_index': 12521,
#         'to_index': 12575,
#         'distance': 53142,
#         'time': 1739.523,
#         'instruction': {'text': 'Keep right to stay on MEX 180D.'},
#         'toll': True},
#        {'from_index': 12575,
#         'to_index': 12664,
#         'distance': 15839,
#         'time': 630.515,
#         'instruction': {'text': 'Keep right to take Q.ROO 180.'},
#         'toll': True},
#        {'from_index': 12664,
#         'to_index': 12848,
#         'distance': 16509,
#         'time': 857.312,
#         'instruction': {'text': 'Stay straight to take the MEX 307 ramp.'}},
#        {'from_index': 12848,
#         'to_index': 12874,
#         'distance': 157,
#         'time': 19.82,
#         'instruction': {'text': 'Enter the roundabout and take the 3rd exit onto Avenida Tulúm/MEX 307.'}},
#        {'from_index': 12874,
#         'to_index': 12895,
#         'distance': 1098,
#         'time': 88.578,
#         'instruction': {'text': 'Exit the roundabout onto Avenida Tulúm/MEX 307.'}},
#        {'from_index': 12895,
#         'to_index': 12905,
#         'distance': 528,
#         'time': 32.632,
#         'instruction': {'text': 'Turn right toward MEX 180.'}},
#        {'from_index': 12905,
#         'to_index': 12962,
#         'distance': 4384,
#         'time': 280.031,
#         'instruction': {'text': 'Keep left to stay on Avenida López Portillo/MEX 180.'}},
#        {'from_index': 12962,
#         'to_index': 12964,
#         'distance': 294,
#         'time': 32.398,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 12964,
#         'to_index': 13002,
#         'distance': 2796,
#         'time': 173.14,
#         'instruction': {'text': 'Turn right onto Prolongación Avenida Bonampak.'}},
#        {'from_index': 13002,
#         'to_index': 13007,
#         'distance': 19,
#         'time': 2.359,
#         'instruction': {'text': 'Enter the roundabout and take the 1st exit onto Avenida López Portillo/MEX 180.'}},
#        {'from_index': 13007,
#         'to_index': 13012,
#         'distance': 219,
#         'time': 23.125,
#         'instruction': {'text': 'Exit the roundabout onto Avenida López Portillo/MEX 180.'}},
#        {'from_index': 13012,
#         'to_index': 13021,
#         'distance': 263,
#         'time': 24.203,
#         'instruction': {'text': 'Bear left.'}},
#        {'from_index': 13021,
#         'to_index': 13028,
#         'distance': 6257,
#         'time': 1126.257,
#         'instruction': {'text': 'Take the Ferry Ruta Puerto Juárez - Isla Mujeres Ferry.'},
#         'ferry': True},
#        {'from_index': 13028,
#         'to_index': 13031,
#         'distance': 73,
#         'time': 10.515,
#         'instruction': {'text': 'Drive east.'}},
#        {'from_index': 13031,
#         'to_index': 13065,
#         'distance': 1963,
#         'time': 141.71,
#         'instruction': {'text': 'Turn right onto Avenida Rueda Medina.'}},
#        {'from_index': 13065,
#         'to_index': 13073,
#         'distance': 32,
#         'time': 10.585,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 13073,
#         'to_index': 13092,
#         'distance': 332,
#         'time': 34.406,
#         'instruction': {'text': 'Bear right onto Circuito Colonias.'}},
#        {'from_index': 13092,
#         'to_index': 13099,
#         'distance': 359,
#         'time': 58.093,
#         'instruction': {'text': 'Turn right onto Calle Jesús Martínez Ross.'}},
#        {'from_index': 13099,
#         'to_index': 13099,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the right.'}}]},
#      {'distance': 707947,
#       'time': 28479.886,
#       'steps': [{'from_index': 0,
#         'to_index': 9,
#         'distance': 617,
#         'time': 44.484,
#         'instruction': {'text': 'Drive southeast on Calle Jesús Martínez Ross.'}},
#        {'from_index': 9,
#         'to_index': 11,
#         'distance': 56,
#         'time': 9.66,
#         'instruction': {'text': 'Turn left onto Manuel Oriso Godoy.'}},
#        {'from_index': 11,
#         'to_index': 14,
#         'distance': 129,
#         'time': 18.778,
#         'instruction': {'text': 'Turn left onto Calle Facundo Rosado.'}},
#        {'from_index': 14,
#         'to_index': 31,
#         'distance': 855,
#         'time': 91.775,
#         'instruction': {'text': 'Bear right onto Calle Jesús Martínez Ross.'}},
#        {'from_index': 31,
#         'to_index': 56,
#         'distance': 378,
#         'time': 44.646,
#         'instruction': {'text': 'Turn left onto Circuito Colonias.'}},
#        {'from_index': 56,
#         'to_index': 87,
#         'distance': 1926,
#         'time': 138.843,
#         'instruction': {'text': 'Bear right onto Avenida Rueda Medina.'}},
#        {'from_index': 87,
#         'to_index': 90,
#         'distance': 73,
#         'time': 11.239,
#         'instruction': {'text': 'Turn left.'}},
#        {'from_index': 90,
#         'to_index': 97,
#         'distance': 6257,
#         'time': 1126.259,
#         'instruction': {'text': 'Take the Ferry Ruta Puerto Juárez - Isla Mujeres Ferry.'},
#         'ferry': True},
#        {'from_index': 97,
#         'to_index': 106,
#         'distance': 263,
#         'time': 24.245,
#         'instruction': {'text': 'Drive west.'}},
#        {'from_index': 106,
#         'to_index': 116,
#         'distance': 222,
#         'time': 22.976,
#         'instruction': {'text': 'Bear right onto Avenida López Portillo/MEX 180.'}},
#        {'from_index': 116,
#         'to_index': 126,
#         'distance': 49,
#         'time': 8.728,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto Prolongación Avenida Bonampak.'}},
#        {'from_index': 126,
#         'to_index': 164,
#         'distance': 2835,
#         'time': 170.188,
#         'instruction': {'text': 'Exit the roundabout onto Prolongación Avenida Bonampak.'}},
#        {'from_index': 164,
#         'to_index': 173,
#         'distance': 79,
#         'time': 5.652,
#         'instruction': {'text': 'Make a left U-turn to stay on Prolongación Avenida Bonampak.'}},
#        {'from_index': 173,
#         'to_index': 175,
#         'distance': 294,
#         'time': 26.831,
#         'instruction': {'text': 'Turn right.'}},
#        {'from_index': 175,
#         'to_index': 222,
#         'distance': 3850,
#         'time': 245.954,
#         'instruction': {'text': 'Turn right onto Avenida López Portillo/MEX 180.'}},
#        {'from_index': 222,
#         'to_index': 286,
#         'distance': 3945,
#         'time': 249.589,
#         'instruction': {'text': 'Keep left to stay on Avenida López Portillo/MEX 180.'}},
#        {'from_index': 286,
#         'to_index': 292,
#         'distance': 57,
#         'time': 7.528,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit toward Merida.'}},
#        {'from_index': 292,
#         'to_index': 467,
#         'distance': 14134,
#         'time': 774.867,
#         'instruction': {'text': 'Exit the roundabout toward Merida.'}},
#        {'from_index': 467,
#         'to_index': 1128,
#         'distance': 285762,
#         'time': 9859.447,
#         'instruction': {'text': 'Keep left to stay on MEX 180.'},
#         'toll': True},
#        {'from_index': 1128,
#         'to_index': 1143,
#         'distance': 205,
#         'time': 37.849,
#         'instruction': {'text': 'Enter the roundabout and take the 3rd exit onto Calle 10.'}},
#        {'from_index': 1143,
#         'to_index': 1152,
#         'distance': 368,
#         'time': 33.214,
#         'instruction': {'text': 'Exit the roundabout onto Calle 10.'}},
#        {'from_index': 1152,
#         'to_index': 1255,
#         'distance': 13121,
#         'time': 527.718,
#         'instruction': {'text': 'Bear right onto Anillo Periférico Licenciado Manuel Berzunza.'}},
#        {'from_index': 1255,
#         'to_index': 2199,
#         'distance': 166342,
#         'time': 6622.341,
#         'instruction': {'text': 'Take the MEX 180 exit toward Campeche/Uxmal.'}},
#        {'from_index': 2199,
#         'to_index': 3045,
#         'distance': 162681,
#         'time': 6390.562,
#         'instruction': {'text': 'Take the ramp.'},
#         'toll': True},
#        {'from_index': 3045,
#         'to_index': 3050,
#         'distance': 12,
#         'time': 1.166,
#         'instruction': {'text': 'Enter the roundabout and take the 2nd exit onto MEX 180D/Avenida Puente de la Unidad.'}},
#        {'from_index': 3050,
#         'to_index': 3338,
#         'distance': 39001,
#         'time': 1687.126,
#         'instruction': {'text': 'Exit the roundabout onto MEX 180D/Avenida Puente de la Unidad.'},
#         'toll': True},
#        {'from_index': 3338,
#         'to_index': 3360,
#         'distance': 1109,
#         'time': 55.044,
#         'instruction': {'text': 'Bear left onto MEX 180/Avenida Isla de Tris. Continue on MEX 180.'}},
#        {'from_index': 3360,
#         'to_index': 3414,
#         'distance': 2154,
#         'time': 104.761,
#         'instruction': {'text': 'Turn left onto MEX 180/Avenida Luis D. Colosio.'}},
#        {'from_index': 3414,
#         'to_index': 3421,
#         'distance': 464,
#         'time': 49.021,
#         'instruction': {'text': 'Turn right onto Calle 15.'}},
#        {'from_index': 3421,
#         'to_index': 3423,
#         'distance': 179,
#         'time': 19.888,
#         'instruction': {'text': 'Turn right onto Calle 28-A.'}},
#        {'from_index': 3423,
#         'to_index': 3425,
#         'distance': 129,
#         'time': 17.449,
#         'instruction': {'text': 'Turn left onto Calle 17.'}},
#        {'from_index': 3425,
#         'to_index': 3430,
#         'distance': 216,
#         'time': 24.007,
#         'instruction': {'text': 'Turn right onto Calle 22.'}},
#        {'from_index': 3430,
#         'to_index': 3434,
#         'distance': 130,
#         'time': 16.875,
#         'instruction': {'text': 'Turn left onto Calle 23.'}},
#        {'from_index': 3434,
#         'to_index': 3435,
#         'distance': 51,
#         'time': 11.158,
#         'instruction': {'text': 'Turn left onto Calle 20.'}},
#        {'from_index': 3435,
#         'to_index': 3435,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the right.'}}]},
#      {'distance': 1538239,
#       'time': 54399.339,
#       'steps': [{'from_index': 0,
#         'to_index': 3,
#         'distance': 131,
#         'time': 13.543,
#         'instruction': {'text': 'Drive southeast on Calle 20.'}},
#        {'from_index': 3,
#         'to_index': 8,
#         'distance': 212,
#         'time': 21.863,
#         'instruction': {'text': 'Turn left onto Calle 17.'}},
#        {'from_index': 8,
#         'to_index': 25,
#         'distance': 640,
#         'time': 67.545,
#         'instruction': {'text': 'Turn right onto Calle 28.'}},
#        {'from_index': 25,
#         'to_index': 1000,
#         'distance': 162427,
#         'time': 6503.347,
#         'instruction': {'text': 'Make a right U-turn onto MEX 180D.'},
#         'toll': True},
#        {'from_index': 1000,
#         'to_index': 1335,
#         'distance': 75539,
#         'time': 2738.723,
#         'instruction': {'text': 'Turn right to take the ramp toward Nacajuca.'},
#         'toll': True},
#        {'from_index': 1335,
#         'to_index': 1810,
#         'distance': 84348,
#         'time': 3068.427,
#         'instruction': {'text': 'Keep left to stay on MEX 180D.'}},
#        {'from_index': 1810,
#         'to_index': 1995,
#         'distance': 11898,
#         'time': 408.14,
#         'instruction': {'text': 'Keep right to stay on MEX 180D.'},
#         'toll': True},
#        {'from_index': 1995,
#         'to_index': 3270,
#         'distance': 248365,
#         'time': 8417.041,
#         'instruction': {'text': 'Keep left to stay on MEX 180D.'},
#         'toll': True},
#        {'from_index': 3270,
#         'to_index': 3297,
#         'distance': 2272,
#         'time': 77.97,
#         'instruction': {'text': 'Keep left to take MEX 145D.'}},
#        {'from_index': 3297,
#         'to_index': 3594,
#         'distance': 31216,
#         'time': 1030.083,
#         'instruction': {'text': 'Take the MEX 150D exit toward Córdoba/Orizaba/Puebla/México.'}},
#        {'from_index': 3594,
#         'to_index': 3912,
#         'distance': 38929,
#         'time': 1328.865,
#         'instruction': {'text': 'Keep left to stay on MEX 150D.'},
#         'toll': True},
#        {'from_index': 3912,
#         'to_index': 5614,
#         'distance': 134214,
#         'time': 4584.691,
#         'instruction': {'text': 'Keep left to stay on MEX 150D.'},
#         'toll': True},
#        {'from_index': 5614,
#         'to_index': 5678,
#         'distance': 12676,
#         'time': 550.945,
#         'instruction': {'text': 'Keep left to stay on MEX 150D.'},
#         'toll': True},
#        {'from_index': 5678,
#         'to_index': 6000,
#         'distance': 36529,
#         'time': 1422.308,
#         'instruction': {'text': 'Keep right to stay on MEX 150D.'},
#         'toll': True},
#        {'from_index': 6000,
#         'to_index': 6002,
#         'distance': 145,
#         'time': 6.224,
#         'instruction': {'text': 'Take the MEX 150D exit.'}},
#        {'from_index': 6002,
#         'to_index': 7484,
#         'distance': 224879,
#         'time': 7735.679,
#         'instruction': {'text': 'Keep right to take MEX M40D.'},
#         'toll': True},
#        {'from_index': 7484,
#         'to_index': 8712,
#         'distance': 145929,
#         'time': 4952.863,
#         'instruction': {'text': 'Take the MEX 15D exit toward Guadalajara/Morelia.'},
#         'toll': True},
#        {'from_index': 8712,
#         'to_index': 9465,
#         'distance': 62873,
#         'time': 2152.425,
#         'instruction': {'text': 'Take the MEX 37D exit toward Uruapan/Morelia.'},
#         'toll': True},
#        {'from_index': 9465,
#         'to_index': 9849,
#         'distance': 44769,
#         'time': 1542.976,
#         'instruction': {'text': 'Bear left onto MEX 14D.'},
#         'toll': True},
#        {'from_index': 9849,
#         'to_index': 12341,
#         'distance': 218070,
#         'time': 7592.429,
#         'instruction': {'text': 'Take the MEX 37D exit toward Lazaro Cardenas/Zihuatanejo.'},
#         'toll': True},
#        {'from_index': 12341,
#         'to_index': 12364,
#         'distance': 1419,
#         'time': 104.007,
#         'instruction': {'text': 'Turn left onto Avenida Lázaro Cárdenas.'}},
#        {'from_index': 12364,
#         'to_index': 12374,
#         'distance': 397,
#         'time': 34.726,
#         'instruction': {'text': 'Turn right onto Avenida Heroica Escuela Naval Militar.'}},
#        {'from_index': 12374,
#         'to_index': 12379,
#         'distance': 331,
#         'time': 35.089,
#         'instruction': {'text': 'Turn left onto Avenida Rector Hidalgo.'}},
#        {'from_index': 12379,
#         'to_index': 12381,
#         'distance': 30,
#         'time': 9.417,
#         'instruction': {'text': 'Turn left onto Calle Niño Artillero.'}},
#        {'from_index': 12381,
#         'to_index': 12381,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]},
#      {'distance': 329771,
#       'time': 13402.294,
#       'steps': [{'from_index': 0,
#         'to_index': 1,
#         'distance': 114,
#         'time': 13.719,
#         'instruction': {'text': 'Drive northeast on Calle Niño Artillero.'}},
#        {'from_index': 1,
#         'to_index': 5,
#         'distance': 317,
#         'time': 43.496,
#         'instruction': {'text': 'Turn left onto Calle Hermenegildo Galeana.'}},
#        {'from_index': 5,
#         'to_index': 13,
#         'distance': 268,
#         'time': 22.585,
#         'instruction': {'text': 'Turn right onto Avenida Heroica Escuela Naval Militar.'}},
#        {'from_index': 13,
#         'to_index': 33,
#         'distance': 1376,
#         'time': 100.521,
#         'instruction': {'text': 'Turn left onto Avenida Lázaro Cárdenas.'}},
#        {'from_index': 33,
#         'to_index': 56,
#         'distance': 1132,
#         'time': 55.777,
#         'instruction': {'text': 'Make a sharp right onto Boulevard de las Islas.'}},
#        {'from_index': 56,
#         'to_index': 169,
#         'distance': 28145,
#         'time': 1132.888,
#         'instruction': {'text': 'Bear right onto Boulevard de los Ríos.'},
#         'toll': True},
#        {'from_index': 169,
#         'to_index': 184,
#         'distance': 259,
#         'time': 12.126,
#         'instruction': {'text': 'Take the exit.'},
#         'toll': True},
#        {'from_index': 184,
#         'to_index': 203,
#         'distance': 243,
#         'time': 11.84,
#         'instruction': {'text': 'Keep left at the fork.'}},
#        {'from_index': 203,
#         'to_index': 398,
#         'distance': 23240,
#         'time': 930.159,
#         'instruction': {'text': 'Bear right onto MEX 200/Zihuatanejo - La Mira.'}},
#        {'from_index': 398,
#         'to_index': 599,
#         'distance': 17433,
#         'time': 698.165,
#         'instruction': {'text': 'Keep right to stay on MEX 200.'}},
#        {'from_index': 599,
#         'to_index': 929,
#         'distance': 29946,
#         'time': 1224.634,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 929,
#         'to_index': 2937,
#         'distance': 184616,
#         'time': 7366.052,
#         'instruction': {'text': 'Keep left to stay on MEX 200.'}},
#        {'from_index': 2937,
#         'to_index': 3234,
#         'distance': 22331,
#         'time': 866.409,
#         'instruction': {'text': 'Keep right to stay on MEX 200.'}},
#        {'from_index': 3234,
#         'to_index': 3240,
#         'distance': 127,
#         'time': 5.952,
#         'instruction': {'text': 'Stay straight to take the ramp.'}},
#        {'from_index': 3240,
#         'to_index': 3391,
#         'distance': 8352,
#         'time': 335.636,
#         'instruction': {'text': 'Bear right onto MEX 200/Carretera Acapulco-Zihuatanejo. Continue on MEX 200.'}},
#        {'from_index': 3391,
#         'to_index': 3673,
#         'distance': 8998,
#         'time': 377.503,
#         'instruction': {'text': 'Bear left onto MEX 200/Carretera Nacional Acapulco-Zihuatanejo.'}},
#        {'from_index': 3673,
#         'to_index': 3697,
#         'distance': 1179,
#         'time': 58.176,
#         'instruction': {'text': 'Keep left to take MEX 200.'}},
#        {'from_index': 3697,
#         'to_index': 3706,
#         'distance': 834,
#         'time': 46.704,
#         'instruction': {'text': 'Turn left onto MEX 200/Avenida Costera Miguel Alemán.'}},
#        {'from_index': 3706,
#         'to_index': 3712,
#         'distance': 293,
#         'time': 31.601,
#         'instruction': {'text': 'Turn left onto Calle Gabriel Avilés.'}},
#        {'from_index': 3712,
#         'to_index': 3716,
#         'distance': 221,
#         'time': 15.333,
#         'instruction': {'text': 'Turn right onto Avenida Cuauhtémoc.'}},
#        {'from_index': 3716,
#         'to_index': 3718,
#         'distance': 213,
#         'time': 31.191,
#         'instruction': {'text': 'Turn left onto Calle Michoacán.'}},
#        {'from_index': 3718,
#         'to_index': 3721,
#         'distance': 99,
#         'time': 13.515,
#         'instruction': {'text': 'Turn right onto Avenida Sonora.'}},
#        {'from_index': 3721,
#         'to_index': 3722,
#         'distance': 30,
#         'time': 8.3,
#         'instruction': {'text': 'Turn left onto Calle Vicente Guerrero.'}},
#        {'from_index': 3722,
#         'to_index': 3722,
#         'distance': 0,
#         'time': 0,
#         'instruction': {'text': 'Your destination is on the left.'}}]}],
#     'toll': True,
#     'ferry': True},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[
#       [-101.479893, 17.639616],
#       [-101.479692, 17.639646],
#       [-101.479105, 17.63974],
#       [-101.479, 17.639748],
#       [-101.478687, 17.639771],
#       [-101.478575, 17.639774],
#       [-101.478263, 17.639703],
#       [-101.477952, 17.639498],
#       [-101.477822, 17.639376],
#       [-101.477758, 17.639306],
#       [-101.477433, 17.638923],
#       [-101.477134, 17.638569],
#       [-101.476828, 17.638198],
#       [-101.476774, 17.638129],
#       [-101.476446, 17.637732],
#       [-101.476198, 17.63739],
#       [-101.475854, 17.636917],
#       [-101.475439, 17.636325],
#       [-101.475371, 17.63621],
#       [-101.47381, 17.634016],
#       [-101.473696, 17.633876],
#       [-101.4735, 17.633659],
#       [-101.47332, 17.633509],
#       [-101.473194, 17.633403],
#       [-101.472415, 17.632909],
#       [-101.472229, 17.632784],
#       [-101.471999, 17.63264],
#       [-101.471369, 17.632225],
#       [-101.470788, 17.631837],
#       [-101.470402, 17.631604],
#       [-101.469838, 17.631245],
#       [-101.468453, 17.630326],
#       [-101.468116, 17.630101],
#       [-101.468029, 17.630036],
#       [-101.467872, 17.62994],
#       [-101.467683, 17.629816],
#       [-101.46649, 17.629037],
#       [-101.466436, 17.629002],
#       [-101.465084, 17.628108],
#       ...]]}}],
#  'properties': {'mode': 'drive',
#   'waypoints': [{'lat': 16.8634, 'lon': -99.8901},
#    {'lat': 21.2311, 'lon': -86.731},
#    {'lat': 18.6333, 'lon': -91.8333},
#    {'lat': 17.9583, 'lon': -102.2},
#    {'lat': 16.8634, 'lon': -99.8901}],
#   'units': 'metric'},
#  'type': 'FeatureCollection'}

# %% [markdown]
# ## From the JSON response, store the route's legs coordinates in a variable called `legs`

# %%
import json
legs = route_resources["legs"][0]["distance"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 2>()
#       1 import json
# ----> 2 legs = route_resources["legs"][0]["distance"]
#
# NameError: name 'route_resources' is not defined

# %%
# Fetch the route's legs coordinates from the JSON reponse
legs = # YOUR CODE HERE

# %% [markdown]
# ## Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude value into two Python lists names `longitude` and `latitude`

# %%
# Create and empty list to store the longitude of each step
# YOUR CODE HERE

# Create and empty list to store the latitude of step
# YOUR CODE HERE

# Loop through the legs coordinates to fetch the latitude and longitude for each step
# YOUR CODE HERE

# %% [markdown]
# ## Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`

# %%
# Create an empty DataFrame to store the steps' coordinates
route_df = # YOUR CODE HERE

# Add the steps' longitude and latitude from each step as columns to the DataFrame
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#    longitude   latitude
# 0  12.479944  41.889982
# 1  12.479927  41.890012
# 2  12.479760  41.890249
# 3  12.479580  41.890493
# 4  12.479418  41.890662

# %% [markdown]
# ##  Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map

# %%
# Configure the route path by using the GeoViews' Path function
route_path = # YOUR CODE HERE

# %%
# Display a composed plot by using the route_map and route_path objects
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
#    .Path.I   :Path   [longitude,latitude]
