# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?id=524901&appid=" + weather_api_key + "&units=imperial"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_desc})   
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | meulaboh
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | atar
# Processing Record 5 of Set 1 | college
# Processing Record 6 of Set 1 | ancud
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | dicabisagan
# Processing Record 11 of Set 1 | gold coast
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | sotouboua
# Processing Record 15 of Set 1 | hambantota
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | pangody
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | lekoni
# Processing Record 22 of Set 1 | nelson bay
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | jardim
# Processing Record 25 of Set 1 | muros
# Processing Record 26 of Set 1 | manicore
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | bure
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | broome
# Processing Record 32 of Set 1 | sao joao da barra
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | maniitsoq
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | grand gaube
# Processing Record 37 of Set 1 | kuala terengganu
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | te anau
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | sabha
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | awbari
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | strezhevoy
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | chumikan
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | srednekolymsk
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | tangi
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | quatre cocos
# Processing Record 13 of Set 2 | bealanana
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 2 | general roca
# Processing Record 20 of Set 2 | chapais
# Processing Record 21 of Set 2 | tura
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | bani walid
# Processing Record 28 of Set 2 | diego de almagro
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | canora
# Processing Record 31 of Set 2 | sayat
# Processing Record 32 of Set 2 | lasa
# Processing Record 33 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | ikalamavony
# Processing Record 36 of Set 2 | seoul
# Processing Record 37 of Set 2 | vaini
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | tual
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | kaeo
# Processing Record 42 of Set 2 | watsa
# Processing Record 43 of Set 2 | punta arenas
# Processing Record 44 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | yinchuan
# Processing Record 46 of Set 2 | baiyin
# Processing Record 47 of Set 2 | olinda
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | ambon
# Processing Record 2 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 3 | gat
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | merauke
# Processing Record 7 of Set 3 | bandarban
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 3 | sarkand
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | areosa
# Processing Record 13 of Set 3 | sovetskiy
# Processing Record 14 of Set 3 | keetmanshoop
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | eureka
# Processing Record 18 of Set 3 | ukiah
# Processing Record 19 of Set 3 | cockburn town
# Processing Record 20 of Set 3 | yumen
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | nome
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | onega
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | parys
# Processing Record 31 of Set 3 | nouakchott
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | marystown
# Processing Record 34 of Set 3 | kholm-zhirkovskiy
# Processing Record 35 of Set 3 | kushiro
# Processing Record 36 of Set 3 | kijang
# Processing Record 37 of Set 3 | ocos
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | arkhangelos
# City not found. Skipping...
# Processing Record 40 of Set 3 | teahupoo
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | tsuruoka
# Processing Record 43 of Set 3 | karratha
# Processing Record 44 of Set 3 | elko
# Processing Record 45 of Set 3 | puerto escondido
# Processing Record 46 of Set 3 | pishin
# Processing Record 47 of Set 3 | bage
# Processing Record 48 of Set 3 | guiratinga
# Processing Record 49 of Set 3 | rayong
# Processing Record 50 of Set 3 | defiance
# Processing Record 1 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 4 | santa maria
# Processing Record 3 of Set 4 | ballina
# Processing Record 4 of Set 4 | punta de piedra
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | asosa
# Processing Record 7 of Set 4 | sao gabriel da cachoeira
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | hwange
# Processing Record 11 of Set 4 | konstantinovka
# Processing Record 12 of Set 4 | araouane
# Processing Record 13 of Set 4 | elk point
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | solnechnyy
# Processing Record 16 of Set 4 | santa rosa
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | preeceville
# Processing Record 19 of Set 4 | maldonado
# Processing Record 20 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | umm lajj
# Processing Record 23 of Set 4 | ryazan
# Processing Record 24 of Set 4 | nyaunglebin
# Processing Record 25 of Set 4 | bom jesus
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | sao francisco do sul
# Processing Record 28 of Set 4 | puerto narino
# Processing Record 29 of Set 4 | whitehorse
# Processing Record 30 of Set 4 | ucluelet
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | taltal
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 4 | mayo
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | qasigiannguit
# Processing Record 39 of Set 4 | oktyabrskiy
# Processing Record 40 of Set 4 | gubkinskiy
# Processing Record 41 of Set 4 | burnie
# Processing Record 42 of Set 4 | port augusta
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | taoudenni
# Processing Record 45 of Set 4 | port moresby
# Processing Record 46 of Set 4 | kovur
# Processing Record 47 of Set 4 | tilichiki
# Processing Record 48 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 4 | changji
# Processing Record 50 of Set 4 | romny
# Processing Record 1 of Set 5 | glendive
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | naron
# Processing Record 4 of Set 5 | sao paulo de olivenca
# Processing Record 5 of Set 5 | sanchor
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | sijunjung
# Processing Record 8 of Set 5 | shiraz
# Processing Record 9 of Set 5 | san julian
# Processing Record 10 of Set 5 | tautira
# Processing Record 11 of Set 5 | koboldo
# City not found. Skipping...
# Processing Record 12 of Set 5 | amalapuram
# Processing Record 13 of Set 5 | atuona
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | eldorado
# Processing Record 17 of Set 5 | madimba
# Processing Record 18 of Set 5 | opuwo
# Processing Record 19 of Set 5 | caravelas
# Processing Record 20 of Set 5 | sangin
# Processing Record 21 of Set 5 | birao
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | lieksa
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 5 | namtsy
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | tiarei
# Processing Record 31 of Set 5 | mozarlandia
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | yaan
# Processing Record 34 of Set 5 | arman
# Processing Record 35 of Set 5 | necochea
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | palkaka
# City not found. Skipping...
# Processing Record 38 of Set 5 | ixtapa
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | dalvik
# Processing Record 42 of Set 5 | utete
# Processing Record 43 of Set 5 | kangaba
# Processing Record 44 of Set 5 | kennett
# Processing Record 45 of Set 5 | honningsvag
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | xiangdong
# City not found. Skipping...
# Processing Record 48 of Set 5 | verkhnyaya inta
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | labuhan
# Processing Record 2 of Set 6 | asau
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | kimparana
# Processing Record 5 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 6 | bajil
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | turan
# Processing Record 9 of Set 6 | dikson
# Processing Record 10 of Set 6 | mogadishu
# Processing Record 11 of Set 6 | kodinsk
# Processing Record 12 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 13 of Set 6 | mamanguape
# Processing Record 14 of Set 6 | kitimat
# Processing Record 15 of Set 6 | vestmannaeyjar
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | dangeni
# Processing Record 18 of Set 6 | irece
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 6 | ushtobe
# Processing Record 23 of Set 6 | jumla
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | kyren
# Processing Record 26 of Set 6 | chastyye
# Processing Record 27 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | tayabo
# Processing Record 31 of Set 6 | vila
# Processing Record 32 of Set 6 | zhangzhou
# Processing Record 33 of Set 6 | arona
# Processing Record 34 of Set 6 | kargil
# Processing Record 35 of Set 6 | clyde river
# Processing Record 36 of Set 6 | rosarito
# Processing Record 37 of Set 6 | kieta
# Processing Record 38 of Set 6 | garowe
# Processing Record 39 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 40 of Set 6 | borovoy
# Processing Record 41 of Set 6 | nicoya
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | zhigansk
# Processing Record 44 of Set 6 | igrim
# Processing Record 45 of Set 6 | natal
# Processing Record 46 of Set 6 | mount pleasant
# Processing Record 47 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | corvallis
# Processing Record 49 of Set 6 | sandpoint
# Processing Record 50 of Set 6 | airai
# Processing Record 1 of Set 7 | chokurdakh
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | haimen
# Processing Record 5 of Set 7 | avera
# Processing Record 6 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | zhanakorgan
# Processing Record 9 of Set 7 | port hawkesbury
# Processing Record 10 of Set 7 | maraa
# Processing Record 11 of Set 7 | makakilo city
# Processing Record 12 of Set 7 | marienburg
# Processing Record 13 of Set 7 | maloy
# Processing Record 14 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 7 | phuket
# Processing Record 16 of Set 7 | roald
# Processing Record 17 of Set 7 | wattegama
# Processing Record 18 of Set 7 | zaysan
# Processing Record 19 of Set 7 | portland
# Processing Record 20 of Set 7 | virginia beach
# Processing Record 21 of Set 7 | athabasca
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | ayagoz
# Processing Record 24 of Set 7 | lavrentiya
# Processing Record 25 of Set 7 | kamina
# Processing Record 26 of Set 7 | achit
# Processing Record 27 of Set 7 | pangai
# Processing Record 28 of Set 7 | montevideo
# Processing Record 29 of Set 7 | botwood
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | domoni
# Processing Record 33 of Set 7 | ribeira grande
# Processing Record 34 of Set 7 | omboue
# Processing Record 35 of Set 7 | maiduguri
# Processing Record 36 of Set 7 | yulara
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | banda aceh
# Processing Record 39 of Set 7 | nayoro
# Processing Record 40 of Set 7 | paravola
# Processing Record 41 of Set 7 | acapulco
# Processing Record 42 of Set 7 | visby
# Processing Record 43 of Set 7 | simi
# Processing Record 44 of Set 7 | vikhorevka
# Processing Record 45 of Set 7 | chimbarongo
# Processing Record 46 of Set 7 | nagato
# Processing Record 47 of Set 7 | berbera
# Processing Record 48 of Set 7 | kurchum
# Processing Record 49 of Set 7 | faya
# Processing Record 50 of Set 7 | olenegorsk
# Processing Record 1 of Set 8 | carutapera
# Processing Record 2 of Set 8 | kamariotissa
# Processing Record 3 of Set 8 | ust-kuyga
# Processing Record 4 of Set 8 | nova olimpia
# Processing Record 5 of Set 8 | abu dhabi
# Processing Record 6 of Set 8 | shaunavon
# Processing Record 7 of Set 8 | kita
# Processing Record 8 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 8 | cravo norte
# Processing Record 10 of Set 8 | kuah
# Processing Record 11 of Set 8 | san felipe
# Processing Record 12 of Set 8 | adrar
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | sola
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | hazorasp
# Processing Record 18 of Set 8 | khorramshahr
# Processing Record 19 of Set 8 | batagay
# Processing Record 20 of Set 8 | richards bay
# Processing Record 21 of Set 8 | oyama
# Processing Record 22 of Set 8 | camocim
# Processing Record 23 of Set 8 | gravdal
# Processing Record 24 of Set 8 | darabani
# Processing Record 25 of Set 8 | launceston
# Processing Record 26 of Set 8 | half moon bay
# Processing Record 27 of Set 8 | griffith
# Processing Record 28 of Set 8 | peleduy
# Processing Record 29 of Set 8 | oktyabrskoye
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | russell
# Processing Record 32 of Set 8 | yerbogachen
# Processing Record 33 of Set 8 | isla mujeres
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | vanimo
# Processing Record 36 of Set 8 | mabaruma
# Processing Record 37 of Set 8 | baijiantan
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | hamilton
# Processing Record 40 of Set 8 | sioux lookout
# Processing Record 41 of Set 8 | beira
# Processing Record 42 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 8 | shimoda
# Processing Record 44 of Set 8 | boyolangu
# Processing Record 45 of Set 8 | nsoko
# Processing Record 46 of Set 8 | bandarbeyla
# Processing Record 47 of Set 8 | sokolo
# Processing Record 48 of Set 8 | maygatasan
# Processing Record 49 of Set 8 | morton
# Processing Record 50 of Set 8 | muroto
# Processing Record 1 of Set 9 | linxia
# Processing Record 2 of Set 9 | teya
# Processing Record 3 of Set 9 | samarai
# Processing Record 4 of Set 9 | angra
# City not found. Skipping...
# Processing Record 5 of Set 9 | kalangala
# Processing Record 6 of Set 9 | kropotkin
# Processing Record 7 of Set 9 | homer
# Processing Record 8 of Set 9 | ruwi
# Processing Record 9 of Set 9 | caraz
# Processing Record 10 of Set 9 | vyartsilya
# Processing Record 11 of Set 9 | lata
# Processing Record 12 of Set 9 | padang
# Processing Record 13 of Set 9 | udachnyy
# Processing Record 14 of Set 9 | urubicha
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | erzin
# Processing Record 18 of Set 9 | bousso
# Processing Record 19 of Set 9 | deputatskiy
# Processing Record 20 of Set 9 | daru
# Processing Record 21 of Set 9 | kristiansund
# Processing Record 22 of Set 9 | ilo
# Processing Record 23 of Set 9 | alice springs
# Processing Record 24 of Set 9 | byron bay
# Processing Record 25 of Set 9 | is
# City not found. Skipping...
# Processing Record 26 of Set 9 | thunder bay
# Processing Record 27 of Set 9 | hay river
# Processing Record 28 of Set 9 | cayenne
# Processing Record 29 of Set 9 | derzhavinsk
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | calbuco
# Processing Record 32 of Set 9 | linkou
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | ulety
# Processing Record 35 of Set 9 | saint-augustin
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | nurota
# Processing Record 38 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 9 | krasnouralsk
# Processing Record 40 of Set 9 | klyavlino
# Processing Record 41 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 9 | manaus
# Processing Record 43 of Set 9 | san policarpo
# Processing Record 44 of Set 9 | kuznechnoye
# Processing Record 45 of Set 9 | cidreira
# Processing Record 46 of Set 9 | hinton
# Processing Record 47 of Set 9 | dunedin
# Processing Record 48 of Set 9 | marshfield
# Processing Record 49 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | nampa
# Processing Record 2 of Set 10 | olafsvik
# Processing Record 3 of Set 10 | santiago del estero
# Processing Record 4 of Set 10 | bose
# Processing Record 5 of Set 10 | aykhal
# Processing Record 6 of Set 10 | kuminskiy
# Processing Record 7 of Set 10 | neiafu
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | sisimiut
# Processing Record 10 of Set 10 | porto walter
# Processing Record 11 of Set 10 | kudahuvadhoo
# Processing Record 12 of Set 10 | starkville
# Processing Record 13 of Set 10 | berlevag
# Processing Record 14 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 15 of Set 10 | verkh-usugli
# Processing Record 16 of Set 10 | ajdabiya
# Processing Record 17 of Set 10 | dunayivtsi
# City not found. Skipping...
# Processing Record 18 of Set 10 | viedma
# Processing Record 19 of Set 10 | pokaran
# Processing Record 20 of Set 10 | jalu
# Processing Record 21 of Set 10 | murmashi
# Processing Record 22 of Set 10 | mapiri
# Processing Record 23 of Set 10 | iqaluit
# Processing Record 24 of Set 10 | iraray
# Processing Record 25 of Set 10 | mazamari
# Processing Record 26 of Set 10 | raudeberg
# Processing Record 27 of Set 10 | aragats
# Processing Record 28 of Set 10 | moerai
# Processing Record 29 of Set 10 | chegdomyn
# Processing Record 30 of Set 10 | gorontalo
# Processing Record 31 of Set 10 | doume
# Processing Record 32 of Set 10 | salina
# Processing Record 33 of Set 10 | san patricio
# Processing Record 34 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 10 | vlakhopoulon
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | novouzensk
# Processing Record 38 of Set 10 | harper
# Processing Record 39 of Set 10 | camana
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | tucurui
# Processing Record 42 of Set 10 | aranos
# Processing Record 43 of Set 10 | suntar
# Processing Record 44 of Set 10 | omsukchan
# Processing Record 45 of Set 10 | mushie
# Processing Record 46 of Set 10 | kaniama
# Processing Record 47 of Set 10 | hofn
# Processing Record 48 of Set 10 | zhangye
# Processing Record 49 of Set 10 | mama
# Processing Record 50 of Set 10 | nago
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | katsuura
# Processing Record 3 of Set 11 | okhotsk
# Processing Record 4 of Set 11 | moree
# Processing Record 5 of Set 11 | horsham
# Processing Record 6 of Set 11 | a
# City not found. Skipping...
# Processing Record 7 of Set 11 | uarini
# Processing Record 8 of Set 11 | havelock
# Processing Record 9 of Set 11 | jakhal mandi
# City not found. Skipping...
# Processing Record 10 of Set 11 | turukhansk
# Processing Record 11 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 11 | constitucion
# Processing Record 13 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 14 of Set 11 | lensk
# Processing Record 15 of Set 11 | kloulklubed
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | piranshahr
# Processing Record 18 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 11 | veraval
# Processing Record 20 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 11 | bhainsdehi
# Processing Record 22 of Set 11 | coquimbo
# Processing Record 23 of Set 11 | ossora
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | ahuimanu
# Processing Record 26 of Set 11 | fare
# Processing Record 27 of Set 11 | hundested
# Processing Record 28 of Set 11 | pandan
# Processing Record 29 of Set 11 | rahimatpur
# Processing Record 30 of Set 11 | caala
# Processing Record 31 of Set 11 | severo-kurilsk
# Processing Record 32 of Set 11 | canterbury
# Processing Record 33 of Set 11 | selaphum
# Processing Record 34 of Set 11 | smidovich
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | banjar
# Processing Record 37 of Set 11 | rio gallegos
# Processing Record 38 of Set 11 | tinaquillo
# Processing Record 39 of Set 11 | hearst
# Processing Record 40 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 41 of Set 11 | vilyuysk
# Processing Record 42 of Set 11 | pinega
# Processing Record 43 of Set 11 | isangel
# Processing Record 44 of Set 11 | voh
# Processing Record 45 of Set 11 | gizo
# Processing Record 46 of Set 11 | sinnamary
# Processing Record 47 of Set 11 | mount isa
# Processing Record 48 of Set 11 | cienfuegos
# Processing Record 49 of Set 11 | bambanglipuro
# Processing Record 50 of Set 11 | sinazongwe
# Processing Record 1 of Set 12 | bull savanna
# Processing Record 2 of Set 12 | saquena
# Processing Record 3 of Set 12 | ocampo
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | xianshuigu
# Processing Record 6 of Set 12 | uk
# City not found. Skipping...
# Processing Record 7 of Set 12 | cabedelo
# Processing Record 8 of Set 12 | chicama
# Processing Record 9 of Set 12 | lusambo
# Processing Record 10 of Set 12 | shingu
# Processing Record 11 of Set 12 | ishim
# Processing Record 12 of Set 12 | bissau
# Processing Record 13 of Set 12 | corrente
# Processing Record 14 of Set 12 | zeya
# Processing Record 15 of Set 12 | kashary
# Processing Record 16 of Set 12 | zemio
# Processing Record 17 of Set 12 | kikwit
# Processing Record 18 of Set 12 | namibe
# Processing Record 19 of Set 12 | godda
# Processing Record 20 of Set 12 | namatanai
# Processing Record 21 of Set 12 | hobyo
# Processing Record 22 of Set 12 | ishigaki
# Processing Record 23 of Set 12 | mo i rana
# Processing Record 24 of Set 12 | dubrovka
# Processing Record 25 of Set 12 | pio xii
# Processing Record 26 of Set 12 | bethel
# Processing Record 27 of Set 12 | zambezi
# Processing Record 28 of Set 12 | lucea
# Processing Record 29 of Set 12 | aswan
# Processing Record 30 of Set 12 | shagonar
# Processing Record 31 of Set 12 | taunggyi
# Processing Record 32 of Set 12 | ugoofaaru
# Processing Record 33 of Set 12 | kysyl-syr
# Processing Record 34 of Set 12 | iberia
# Processing Record 35 of Set 12 | cabra
# Processing Record 36 of Set 12 | tsumeb
# Processing Record 37 of Set 12 | kruisfontein
# Processing Record 38 of Set 12 | nioro
# Processing Record 39 of Set 12 | inhambane
# Processing Record 40 of Set 12 | kilembe
# Processing Record 41 of Set 12 | bathsheba
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | freeport
# Processing Record 44 of Set 12 | gryazi
# Processing Record 45 of Set 12 | glenwood springs
# Processing Record 46 of Set 12 | grindavik
# Processing Record 47 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 48 of Set 12 | tuy hoa
# Processing Record 49 of Set 12 | villa carlos paz
# Processing Record 50 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 13 | sovetskaya
# Processing Record 2 of Set 13 | ostrovnoy
# Processing Record 3 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 13 | yeniseysk
# Processing Record 5 of Set 13 | sibolga
# Processing Record 6 of Set 13 | mareeba
# Processing Record 7 of Set 13 | itoman
# Processing Record 8 of Set 13 | bayir
# Processing Record 9 of Set 13 | agadez
# Processing Record 10 of Set 13 | staryy nadym
# Processing Record 11 of Set 13 | mandurah
# Processing Record 12 of Set 13 | dera bugti
# Processing Record 13 of Set 13 | paranapanema
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | kunming
# Processing Record 16 of Set 13 | jiayuguan
# Processing Record 17 of Set 13 | bridgetown
# Processing Record 18 of Set 13 | tromso
# Processing Record 19 of Set 13 | poum
# Processing Record 20 of Set 13 | cherat
# Processing Record 21 of Set 13 | eseka
# Processing Record 22 of Set 13 | sao paulo do potengi
# Processing Record 23 of Set 13 | rio cuarto
# Processing Record 24 of Set 13 | astana
# Processing Record 25 of Set 13 | flin flon
# Processing Record 26 of Set 13 | druzhba
# Processing Record 27 of Set 13 | bubaque
# Processing Record 28 of Set 13 | sakakah
# Processing Record 29 of Set 13 | maun
# Processing Record 30 of Set 13 | hukuntsi
# Processing Record 31 of Set 13 | sambava
# Processing Record 32 of Set 13 | knysna
# Processing Record 33 of Set 13 | comodoro rivadavia
# Processing Record 34 of Set 13 | ghosi
# Processing Record 35 of Set 13 | carmen
# Processing Record 36 of Set 13 | nichinan
# Processing Record 37 of Set 13 | tricase
# Processing Record 38 of Set 13 | champerico
# Processing Record 39 of Set 13 | oussouye
# Processing Record 40 of Set 13 | gewane
# Processing Record 41 of Set 13 | falmouth
# Processing Record 42 of Set 13 | smithers
# Processing Record 43 of Set 13 | waipawa
# Processing Record 44 of Set 13 | kroya
# Processing Record 45 of Set 13 | pauini
# Processing Record 46 of Set 13 | komsomolskiy
# Processing Record 47 of Set 13 | quang ngai
# Processing Record 48 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 13 | pechora
# Processing Record 50 of Set 13 | kaliua
# Processing Record 1 of Set 14 | raga
# Processing Record 2 of Set 14 | mokolo
# Processing Record 3 of Set 14 | tabou
# Processing Record 4 of Set 14 | svetlyy
# Processing Record 5 of Set 14 | bereda
# Processing Record 6 of Set 14 | paamiut
# Processing Record 7 of Set 14 | kupang
# Processing Record 8 of Set 14 | lazaro cardenas
# Processing Record 9 of Set 14 | manbij
# Processing Record 10 of Set 14 | pyshchug
# Processing Record 11 of Set 14 | khvorostyanka
# Processing Record 12 of Set 14 | lucapa
# Processing Record 13 of Set 14 | kahului
# Processing Record 14 of Set 14 | liverpool
# Processing Record 15 of Set 14 | chiesanuova
# Processing Record 16 of Set 14 | novikovo
# Processing Record 17 of Set 14 | kabrai
# Processing Record 18 of Set 14 | asfi
# Processing Record 19 of Set 14 | ambilobe
# Processing Record 20 of Set 14 | dondo
# Processing Record 21 of Set 14 | dera din panah
# City not found. Skipping...
# Processing Record 22 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 14 | danville
# Processing Record 24 of Set 14 | kirakira
# Processing Record 25 of Set 14 | vallenar
# Processing Record 26 of Set 14 | isabela
# Processing Record 27 of Set 14 | soe
# Processing Record 28 of Set 14 | puro
# Processing Record 29 of Set 14 | wangqing
# Processing Record 30 of Set 14 | carazinho
# Processing Record 31 of Set 14 | vuktyl
# Processing Record 32 of Set 14 | duekoue
# Processing Record 33 of Set 14 | morondava
# Processing Record 34 of Set 14 | baneh
# Processing Record 35 of Set 14 | svetlogorsk
# Processing Record 36 of Set 14 | kismayo
# Processing Record 37 of Set 14 | aitape
# Processing Record 38 of Set 14 | kopervik
# Processing Record 39 of Set 14 | buraydah
# Processing Record 40 of Set 14 | conceicao do araguaia
# Processing Record 41 of Set 14 | sabzevar
# Processing Record 42 of Set 14 | touho
# Processing Record 43 of Set 14 | presidencia roque saenz pena
# Processing Record 44 of Set 14 | umarkot
# Processing Record 45 of Set 14 | lonevag
# Processing Record 46 of Set 14 | oakland
# Processing Record 47 of Set 14 | kant
# Processing Record 48 of Set 14 | arroyo
# Processing Record 49 of Set 14 | tshikapa
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | ketchikan
# Processing Record 2 of Set 15 | verkhoyansk
# Processing Record 3 of Set 15 | zhireken
# Processing Record 4 of Set 15 | vanavara
# Processing Record 5 of Set 15 | oranjemund
# Processing Record 6 of Set 15 | gomel
# Processing Record 7 of Set 15 | gujar khan
# Processing Record 8 of Set 15 | brownsville
# Processing Record 9 of Set 15 | litovko
# Processing Record 10 of Set 15 | clovis
# Processing Record 11 of Set 15 | polyarnyye zori
# Processing Record 12 of Set 15 | gongzhuling
# Processing Record 13 of Set 15 | lima
# Processing Record 14 of Set 15 | north bend
# Processing Record 15 of Set 15 | bonavista
# Processing Record 16 of Set 15 | maumere
# Processing Record 17 of Set 15 | bandipur
# Processing Record 18 of Set 15 | harlingen
# Processing Record 19 of Set 15 | ribeira brava
# Processing Record 20 of Set 15 | pavlodar
# Processing Record 21 of Set 15 | qaqortoq
# Processing Record 22 of Set 15 | junin
# Processing Record 23 of Set 15 | dolinsk
# Processing Record 24 of Set 15 | jurado
# Processing Record 25 of Set 15 | los llanos de aridane
# Processing Record 26 of Set 15 | thinadhoo
# Processing Record 27 of Set 15 | znamenskoye
# Processing Record 28 of Set 15 | beyla
# Processing Record 29 of Set 15 | minden
# Processing Record 30 of Set 15 | kayerkan
# Processing Record 31 of Set 15 | stirion
# Processing Record 32 of Set 15 | colares
# Processing Record 33 of Set 15 | vila franca do campo
# Processing Record 34 of Set 15 | pecos
# Processing Record 35 of Set 15 | keflavik
# Processing Record 36 of Set 15 | juanjui
# Processing Record 37 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 15 | pangoa
# Processing Record 39 of Set 15 | sirur
# Processing Record 40 of Set 15 | iznik
# Processing Record 41 of Set 15 | kontagora
# Processing Record 42 of Set 15 | axim
# Processing Record 43 of Set 15 | wasilla
# Processing Record 44 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 15 | okha
# Processing Record 46 of Set 15 | champoton
# Processing Record 47 of Set 15 | gigmoto
# Processing Record 48 of Set 15 | la ronge
# Processing Record 49 of Set 15 | korla
# Processing Record 50 of Set 15 | puli
# Processing Record 1 of Set 16 | san-pedro
# Processing Record 2 of Set 16 | mandera
# Processing Record 3 of Set 16 | mamou
# Processing Record 4 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 16 | qabis
# City not found. Skipping...
# Processing Record 6 of Set 16 | tukrah
# Processing Record 7 of Set 16 | egvekinot
# Processing Record 8 of Set 16 | tuchola
# Processing Record 9 of Set 16 | kerema
# Processing Record 10 of Set 16 | kavaratti
# Processing Record 11 of Set 16 | winslow
# Processing Record 12 of Set 16 | sapulpa
# Processing Record 13 of Set 16 | pacifica
# Processing Record 14 of Set 16 | huarmey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Bluff -46.6000  168.3333     63.37        72          84        8.59
# 1     Meulaboh   4.1363   96.1285     74.10        93         100        5.48
# 2         Atar  20.5169  -13.0499     76.57        15           0        6.17
# 3      College  64.8569 -147.8028     12.20        83         100       10.36
# 4        Ancud -41.8697  -73.8203     55.83        85          93        2.46
# 5     Thompson  55.7435  -97.8558     26.76        93         100        3.44
# 6         Chuy -33.6971  -53.4616     63.36        60          72       10.76
# 7  Dicabisagan  17.0818  122.4157     77.23        89         100        8.61
# 8   Gold Coast -28.0000  153.4333     83.16        69         100       18.41
# 9        Kapaa  22.0752 -159.3190     84.18        71          66        7.00
#
#   Country Current Description
# 0      NZ       broken clouds
# 1      ID     overcast clouds
# 2      MR           clear sky
# 3      US          light snow
# 4      CL     overcast clouds
# 5      CA   light shower snow
# 6      UY       broken clouds
# 7      PH          light rain
# 8      AU     overcast clouds
# 9      US       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df[["City", "Country", "Lat", "Lng", "Max Temp",
             "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
new_city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp",
             "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Display sample data
new_city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bluff      NZ -46.6000  168.3333     63.37        72          84
# 1     Meulaboh      ID   4.1363   96.1285     74.10        93         100
# 2         Atar      MR  20.5169  -13.0499     76.57        15           0
# 3      College      US  64.8569 -147.8028     12.20        83         100
# 4        Ancud      CL -41.8697  -73.8203     55.83        85          93
# 5     Thompson      CA  55.7435  -97.8558     26.76        93         100
# 6         Chuy      UY -33.6971  -53.4616     63.36        60          72
# 7  Dicabisagan      PH  17.0818  122.4157     77.23        89         100
# 8   Gold Coast      AU -28.0000  153.4333     83.16        69         100
# 9        Kapaa      US  22.0752 -159.3190     84.18        71          66
#
#    Wind Speed Current Description
# 0        8.59       broken clouds
# 1        5.48     overcast clouds
# 2        6.17           clear sky
# 3       10.36          light snow
# 4        2.46     overcast clouds
# 5        3.44   light shower snow
# 6       10.76       broken clouds
# 7        8.61          light rain
# 8       18.41     overcast clouds
# 9        7.00       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
